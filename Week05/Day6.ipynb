# %% [markdown]
# LRU 算法
#
# https://labuladong.github.io/article/fname.html?fname=LRU算法

# %%
# Least Recently Used

# %%
# 核心数据结构就是双链表和哈希表的结合体

# LFU
# https://github.com/NokiaX300/Notes_Python/blob/main/Week05/Day7.ipynb

# %%
# 哈希表 -> 双链表
#  key  |-> Node(key, val)

# %% [markdown]
# <img src="146.png" style="zoom:50%" />

# %%
class Node: # 双链表的节点类
    def __init__(self, k: int, v: int) -> None:
        self.key = k
        self.val = v
        self.next = None
        self.prev = None

# 双链表 API 只能从尾部插入，也就是说靠尾部的数据是最近使用的，靠头部的数据是最久未使用的。

# %%
# 146. LRU 缓存
# https://leetcode.cn/problems/lru-cache/

# 使用封装好的数据结构
from collections import OrderedDict

class LRUCache:
    def __init__(self, capacity: int):
        self.cap = capacity
        self.cache = OrderedDict()

    def get(self, key: int) -> int:
        if key not in self.cache:
            return -1
        self.cache.move_to_end(key) # 将当前访问的节点移到双向链表尾部
        return self.cache[key]

    def put(self, key: int, value: int) -> None:
        if self.get(key) == -1 and len(self.cache) == self.cap:
            self.cache.popitem(last=False) # Pairs are returned in LIFO order if last is true or FIFO order if false.
        self.cache[key] = value

# Your LRUCache object will be instantiated and called as such:
# obj = LRUCache(capacity)
# param_1 = obj.get(key)
# obj.put(key,value)

# %%
# 146. LRU 缓存
# https://leetcode.cn/problems/lru-cache/

# 使用封装好的数据结构

from collections import OrderedDict
class LRUCache(OrderedDict):
    def __init__(self, capacity: int):
        super().__init__()
        self.capacity = capacity


    def get(self, key: int) -> int:
        if key not in self:
            return -1
        self.move_to_end(key)
        return self[key]

    def put(self, key: int, value: int) -> None:
        if key in self:
            self.move_to_end(key)
        self[key] = value
        if len(self) > self.capacity:
            self.popitem(last=False)

# %%
class DoubleList: # 构建一个双链表，实现几个 LRU 算法必须的 API
    # 头尾虚节点
    def __init__(self) -> None:
        self.head = Node(0, 0)
        self.tail = Node(0, 0)
        self.head.next = self.tail
        self.tail.prev = self.head
        self.size = 0

    # 在链表尾部添加节点 x，时间 O(1)
    def addLast(self, x: Node):
        x.prev = self.tail.prev
        x.next = self.tail
        self.tail.prev.next = x
        self.tail.prev = x
        self.size += 1

    # 删除链表中的 x 节点（x 一定存在），时间 O(1)
    def remove(self, x: Node):
        x.prev.next = x.next
        x.next.prev = x.prev
        self.size -= 1

    # 删除链表中第一个节点，并返回该节点，时间 O(1)
    def removeFirst(self) -> Node:
        if self.head.next == self.tail:
            return None
        first = self.head.next
        self.remove(first)
        return first
    
    # 返回链表长度，时间 O(1)
    def size(self) -> int:
        return self.size

# %%
# 146. LRU 缓存
# https://leetcode.cn/problems/lru-cache/

class Node:
    def __init__(self, k: int, v: int):
        self.key = k
        self.val = v
        self.next = None
        self.prev = None


class LRUCache:
    def __init__(self, capacity: int):
        self.cache = []
        self.map = {}
        self.capacity = capacity

    def get(self, key: int) -> int:
        if key not in self.map:
            return -1
        self.makeRecently(key)
        return self.map[key].val

    def put(self, key: int, value: int) -> None:
        if key in self.map:
            self.deleteKey(key)
        if len(self.cache) == self.capacity:
            self.removeLeastRecently()
        self.addRecently(key, value)


    def makeRecently(self, key: int):
        x = self.map.get(key)
        self.cache.remove(x)
        self.cache.append(x)

    def addRecently(self, key: int, val: int):
        x = Node(key, val)
        self.cache.append(x)
        self.map[key] = x

    def deleteKey(self, key: int):
        x = self.map.get(key)
        self.cache.remove(x)
        self.map.pop(key)

    def removeLeastRecently(self):
        deletedNode = self.cache.pop(0)
        deletedKey = deletedNode.key
        self.map.pop(deletedKey)


# Your LRUCache object will be instantiated and called as such:
# obj = LRUCache(capacity)
# param_1 = obj.get(key)
# obj.put(key,value)

# %%
class Node:
    def __init__(self, k: int, v: int):
        self.key = k
        self.val = v
        self.next = None
        self.prev = None


class LRUCache:
    def makeRecently(self, key: int):
        # 将某个 key 提升为最近使用的
        x = self.map.get(key)
        # 先从链表中删除这个节点
        self.cache.remove(x)
        # 重新插到队尾
        self.cache.append(x)

    def addRecently(self, key: int, val: int):
        # 添加最近使用的元素
        x = Node(key, val)
        # 链表尾部就是最近使用的元素
        self.cache.append(x)
        # 别忘了在 map 中添加 key 的映射
        self.map[key] = x

    def deleteKey(self, key: int):
        # 删除某一个 key
        x = self.map.get(key)
        # 从链表中删除
        self.cache.remove(x)
        # 从 map 中删除
        self.map.pop(key)

    def removeLeastRecently(self):
        # 删除最久未使用的元素
        # 链表头部的第一个元素就是最久未使用的
        deletedNode = self.cache.pop(0)
        # 同时别忘了从 map 中删除它的 key
        deletedKey = deletedNode.key
        self.map.pop(deletedKey)

    def __init__(self, capacity: int):
        self.cache = []
        self.map = {}
        self.capacity = capacity

    def get(self, key: int) -> int:
        # 读操作
        if key not in self.map:
            return -1
        self.makeRecently(key)
        return self.map.get(key).val

    def put(self, key: int, val: int) -> None:
        if key in self.map:
            # 删除旧的数据
            self.deleteKey(key)

        if self.capacity == len(self.cache):
            # 删除最久未使用的元素
            self.removeLeastRecently()
        # 添加为最近使用的元素
        self.addRecently(key, val)

# %%
# 146. LRU 缓存
# https://leetcode.cn/problems/lru-cache/

# 再写一遍
class Node:
    def __init__(self, k: int, v: int):
        self.key = k
        self.val = v
        self.next = None
        self.prev = None
        

class LRUCache:
    def __init__(self, capacity: int):
        self.capacity = capacity
        self.cache = []
        self.map = {}

    def get(self, key: int) -> int:
        if key not in self.map:
            return -1
        self.makeRecently(key)
        return self.map.get(key).val

    def put(self, key: int, val: int) -> None:
        if key in self.map:
            self.deleteKey(key)
        if len(self.cache) == self.capacity:
            self.removeLeastRecently()
        self.addRecently(key, val)


    def makeRecently(self, key: int):
        x = self.map.get(key)
        self.cache.remove(x)
        self.cache.append(x)

    def addRecently(self, key: int, val: int):
        x = Node(key, val)
        self.cache.append(x) # 链表尾部就是最近使用的元素
        self.map[key] = x
    
    def deleteKey(self, key: int):
        x = self.map.get(key)
        self.cache.remove(x)
        self.map.pop(key)

    def removeLeastRecently(self):
        deletedNode: Node = self.cache.pop(0)
        deletedKey = deletedNode.key
        self.map.pop(deletedKey)

# %%
# 146. LRU 缓存
# https://leetcode.cn/problems/lru-cache/

# 再写一遍
class Node:
    def __init__(self, k: int, v: int) -> None:
        self.key = k
        self.val = v
        self.next = None
        self.prev = None


class LRUCache:
    def __init__(self, capacity: int):
        self.capacity = capacity
        self.cache = []
        self.map = {}

    def get(self, key: int) -> int:
        if key not in self.map:
            return -1
        self.makeRecently(key)
        return self.map.get(key).val
    
    def put(self, key: int, value: int) -> None:
        if key in self.map:
            self.deleteKey(key)
        if len(self.cache) == self.capacity:
            self.removeLeastRecently()
        self.addRecently(key, value)


    def makeRecently(self, key):
        x = self.map.get(key)
        self.cache.remove(x)
        self.cache.append(x)
        
    def addRecently(self, key, val):
        x = Node(key, val)
        self.cache.append(x)
        self.map[key] = x

    def deleteKey(self, key):
        x = self.map.get(key)
        self.cache.remove(x)
        self.map.pop(key)

    def removeLeastRecently(self):
        x: Node = self.cache.pop(0)
        self.map.pop(x.key)


# dict.get(key) 方法在键不存在时返回一个默认值
# 而 dict[key] 表达式在键不存在时会引发 KeyError 异常
# 因此，当你不确定键是否存在时，使用 dict.get(key) 可以更安全地获取字典中的值

# %%
# 146. LRU 缓存
# https://leetcode.cn/problems/lru-cache/

# 再写一遍
class Node:
    def __init__(self, key, val) -> None:
        self.key = key
        self.val = val
        self.prev = None
        self.next = None


class LRUCache:
    def __init__(self, capacity: int):
        self.cache = []
        self.keyToNode = {}
        self.capacity = capacity

    def get(self, key: int) -> int:
        if key not in self.keyToNode:
            return -1
        self.makeRecently(key)
        return self.keyToNode[key].val

    def put(self, key: int, value: int) -> None:
        if key in self.keyToNode:
            self.deleteKey(key)
        if len(self.cache) == self.capacity:
            self.removeLeast()
        self.addRecently(key, value)

    def makeRecently(self, key):
        x = self.keyToNode[key]
        self.cache.remove(x) # 不能使用 pop, pop 接受元素的index
        self.cache.append(x)

    def deleteKey(self, key):
        x = self.keyToNode[key]
        self.cache.remove(x) # remove 接受元素的值
        self.keyToNode.pop(key)
    
    def removeLeast(self):
        x = self.cache.pop(0)
        self.keyToNode.pop(x.key)

    def addRecently(self, key, val):
        x = Node(key, val)
        self.cache.append(x)
        self.keyToNode[key] = x


# Your LRUCache object will be instantiated and called as such:
# obj = LRUCache(capacity)
# param_1 = obj.get(key)
# obj.put(key,value)

# %%
# 146. LRU 缓存
# https://leetcode.cn/problems/lru-cache/

# 再写一遍
class Node:
    def __init__(self, key, val) -> None:
        self.key = key
        self.val = val


class LRUCache:
    def __init__(self, capacity: int):
        self.cache = []
        self.keyToNode = {}
        self.capacity = capacity

    def get(self, key: int) -> int:
        if key not in self.keyToNode:
            return -1
        self.makeRecently(key)
        return self.keyToNode[key].val

    def put(self, key: int, value: int) -> None:
        if key in self.keyToNode:
            self.deleteKey(key)
        if len(self.cache) == self.capacity:
            self.removeLeast()
        self.addRecently(key, value)

    def makeRecently(self, key):
        x = self.keyToNode[key]
        self.cache.remove(x)
        self.cache.append(x)

    def deleteKey(self, key):
        x = self.keyToNode[key]
        self.cache.remove(x)
        self.keyToNode.pop(key)

    def removeLeast(self):
        x = self.cache.pop(0)
        self.keyToNode.pop(x.key)

    def addRecently(self, key, val):
        x = Node(key, val)
        self.cache.append(x)
        self.keyToNode[key] = x


# Your LRUCache object will be instantiated and called as such:
# obj = LRUCache(capacity)
# param_1 = obj.get(key)
# obj.put(key,value)

# %%
# 146. LRU 缓存
# https://leetcode.cn/problems/lru-cache/

# 再写一遍
class Node:
    def __init__(self, key, val):
        self.key = key
        self.val = val

class LRUCache:
    def __init__(self, capacity: int):
        self.capacity = capacity
        self.cache = []
        self.keyToNode = {}

    def get(self, key: int) -> int:
        if key not in self.keyToNode:
            return -1
        self.makeRecently(key)
        return self.keyToNode[key].val

    def put(self, key: int, value: int) -> None:
        if key in self.keyToNode:
            self.deleteKey(key)
        if len(self.cache) == self.capacity:
            self.removeLeast()
        self.addRecently(key, value)

    def makeRecently(self, key):
        node = self.keyToNode[key]
        self.cache.remove(node)
        self.cache.append(node)

    def deleteKey(self, key):
        node = self.keyToNode[key]
        self.keyToNode.pop(key)
        self.cache.remove(node)

    def addRecently(self, key, val):
        node = Node(key, val)
        self.cache.append(node)
        self.keyToNode[key] = node

    def removeLeast(self):
        node = self.cache.pop(0)
        self.keyToNode.pop(node.key)

# %%
# 我劝你们，我把自己LRU，双向链表的这个理念先搞懂
# 146. LRU 缓存
# https://leetcode.cn/problems/lru-cache/

class Node:
    def __init__(self, key=0, val=0) -> None:
        self.key = key
        self.val = val
        self.prev = None
        self.next = None

class LRUCache:
    def __init__(self, capacity) -> None:
        self.capacity = capacity
        self.dummy = Node()
        self.dummy.next = self.dummy
        self.dummy.prev = self.dummy
        self.key_to_node = dict()

    def get(self, key):
        node = self.get_node(key)
        return node.val if node else -1

    def put(self, key, val):
        node = self.get_node(key)
        if node:
            node.val = val
            return
        node = Node(key, val)
        self.key_to_node[key] = node
        self.put_front(node)
        if len(self.key_to_node)>self.capacity:
            node_del = self.dummy.prev
            self.key_to_node.pop(node_del.key)
            node_del.prev.next = node_del.next
            node_del.next.prev = node_del.prev

    def get_node(self, key):
        if key not in self.key_to_node:
            return
        node = self.key_to_node[key]
        node.prev.next = node.next
        node.next.prev = node.prev
        self.put_front(node)
        return node
    
    def put_front(self, node):
        node.prev = self.dummy
        node.next = self.dummy.next
        node.prev.next = node
        node.next.prev = node
